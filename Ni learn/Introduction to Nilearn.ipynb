# %%
from nilearn import plotting

# %%
data_path = "./data/2523412.nii.gz"
plotting.plot_glass_brain(data_path)

# %%
from nilearn import image
smoothed_img = image.smooth_img(data_path, fwhm=5)   
smoothed_img.to_filename("./data/smooth_image.nii")   
data_path2 = "./data/smooth_image.nii"

# %%
first_volume = image.index_img(data_path, 0)   
for volume in image.iter_img("/home/user/fmri_volumes.nii"):
# Out:
# ---------------------------------------------------------------------------
# DimensionError                            Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 first_volume = image.index_img(data_path, 0)
#
# File ~/.local/lib/python3.10/site-packages/nilearn/image/image.py:654, in index_img(imgs, index)
#     601 def index_img(imgs, index):
#     602     """Indexes into a 4D Niimg-like object in the fourth dimension.
#     603
#     604     Common use cases include extracting a 3D image out of `img` or
#    (...)
#     652
#     653     """
# --> 654     imgs = check_niimg_4d(imgs)
#     655     # duck-type for pandas arrays, and select the 'values' attr
#     656     if hasattr(index, 'values') and hasattr(index, 'iloc'):
#
# File ~/.local/lib/python3.10/site-packages/nilearn/_utils/niimg_conversions.py:382, in check_niimg_4d(niimg, return_iterator, dtype)
#     344 def check_niimg_4d(niimg, return_iterator=False, dtype=None):
# ...

# %%
# from nilearn import datasets

# # haxby dataset to have EPI images and masks
# haxby_dataset = datasets.fetch_haxby()

# # print basic information on the dataset
# print('First subject anatomical nifti image (3D) is at: %s' %
#       haxby_dataset.anat[0])
# print('First subject functional nifti image (4D) is at: %s' %
#       haxby_dataset.func[0])  # 4D data

# haxby_anat_filename = haxby_dataset.anat[0]
# haxby_mask_filename = haxby_dataset.mask_vt[0]
# haxby_func_filename = haxby_dataset.func[0]

# # one motor contrast map from NeuroVault
# motor_images = datasets.fetch_neurovault_motor_task()
# stat_img = motor_images.images[0]
